# %% [markdown]
# # Ch 02: Concept 09

# %% [markdown]
# ## using Queues

# %% [markdown]
# 만약 트레이닝 데이터가 많다고 한다면 이것을 모두 한번에 불러오는 것은 힘든 일이다.
#
# 텐서플로우에서 QueueRunner는 효율적인 도구이다. Queue data structure를 통해서 이를 수행할 수 있다.

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# multiple threads를 사용하겠다. 사용할 CPU의 수를 명시해야 한다.

# %%
import multiprocessing
NUM_THREADS = multiprocessing.cpu_count() # 4

# %% [markdown]
# 예제에 사용할 데이터를 생성한다.

# %%
xs = np.random.randn(100, 3)
ys = np.random.randint(0, 2, size=100)

# %% [markdown]
# 여기 우리 데이터에 대한 예제가 있다.

# %%
xs_and_ys = zip(xs, ys)
for _ in range(5):
    x, y = next(xs_and_ys)
    print('Input {}  --->  Output {}'.format(x, y))
# Out:
# Input [ 0.03459827  0.85180779  1.16363823]  --->  Output 1
# Input [ 1.86116909 -2.63707184 -0.24510653]  --->  Output 0
# Input [ 0.32256414 -0.54448053  2.23311806]  --->  Output 0
# Input [-0.59111381  0.97370897  1.82711469]  --->  Output 0
# Input [ 0.4993818   0.86559326 -0.52467918]  --->  Output 0

# %% [markdown]
# queue를 define한다.

# %%
queue = tf.FIFOQueue(capacity=1000, dtypes=[tf.float32, tf.int32])

# %% [markdown]
# enqueue와 dequeue를 set up한다.

# %%
enqueue_op = queue.enqueue_many([xs, ys])
x_op, y_op = queue.dequeue()

# %% [markdown]
# queue runner 를 define한다.

# %%
qr = tf.train.QueueRunner(queue, [enqueue_op] * 4)

# %% [markdown]
# 이제 모든 변수와 ops에 대한 설정이 완료되었다. 세션을 시작해보자.

# %%
sess = tf.InteractiveSession()

# %% [markdown]
# queue runner에 대한 쓰레드를 생성하자.

# %%
coord = tf.train.Coordinator()
enqueue_threads = qr.create_threads(sess, coord=coord, start=True)

# %% [markdown]
# 우리의 dequeue를 test 하자.

# %%
for _ in range(100):
    if coord.should_stop():
        break
    x, y = sess.run([x_op, y_op])
    print(x, y)
coord.request_stop()
coord.join(enqueue_threads)
# Out:
# [ 0.03459826  0.85180777  1.16363823] 1
# [ 1.8611691  -2.63707185 -0.24510653] 0
# [ 0.32256415 -0.5444805   2.23311806] 0
# [-0.59111381  0.97370899  1.8271147 ] 0
# [ 0.49938181  0.86559325 -0.52467918] 0
# [ -3.00911081e-04   1.24408376e+00  -2.68503446e-02] 0
# [-0.32003999  0.30943733  1.17295301] 0
# [-0.74158692  0.53319955  0.2528984 ] 1
# [ 0.38695502  1.94423437  1.06784046] 0
# [ 1.63434303  0.93925041 -0.6698125 ] 1
# [ 0.10698817 -1.31199956  0.01201056] 0
# [ 1.73152852  1.77715683 -1.29911458] 0
# [-1.0566355   1.1012038   0.00128921] 0
# [-0.47042507 -0.79420763  0.46603519] 0
# [-1.37130868 -0.07138771 -0.91868263] 0
# [-1.04607069  0.50373828  0.5067777 ] 0
# [-0.38719022  0.0960427  -0.74320936] 0
# [ 0.20445429 -0.26628113 -1.42132127] 1
# [ 0.0744261   1.12379897 -0.43687195] 1
# [-0.38301447  1.14882672 -0.70178807] 0
# [-0.88415366 -2.10833216 -0.88596445] 1
# [-0.53213567  0.49527898  1.02490401] 0
# [-1.22664678 -0.55283856  0.21844564] 0
# [ 0.20615141 -0.43299392  0.28879598] 0
# [ 0.5992589   1.51104307  0.63877594] 0
# [ 0.1791544  -0.43690604  0.3506147 ] 1
# [ 0.32945612  1.13758767  0.55820346] 0
# [ 0.86217946 -1.11598682 -2.31908059] 1
# [ 2.03996897  1.13415754 -0.57065684] 0
# [-0.72251022 -0.70179188 -0.64749432] 1
# [ 0.94324189  0.77860522  0.32059008] 0
# [-0.61725122 -0.19861738  0.42032263] 0
# [-1.49143398  0.53737962  0.12650073] 1
# [ 2.40520287  0.43662587 -0.38306811] 0
# [ 0.10436175 -1.52476597 -0.74120069] 0
# [-0.50414056 -0.62677246 -0.81163538] 1
# [-0.43852064 -1.88686538 -0.26460788] 1
# [-1.63117576 -0.24333386 -0.13159887] 0
# [-0.30098987 -0.43843386 -0.02344283] 0
# [-1.06808698  0.94477654  0.49694481] 1
# [ 1.76210356  1.02812958  0.05279247] 1
# [ 1.67157102 -0.85318452  0.43693933] 1
# [-2.27853703  0.77694136  1.89081526] 0
# [-1.41944003 -0.12344085 -0.35141647] 0
# [-0.01938228  0.43717393 -1.14486277] 1
# [-0.6788491  -0.36079556 -0.75625104] 1
# [ 1.84952211 -2.50031304  1.68616617] 1
# [ 1.18299282  0.41181585  0.30056286] 0
# [ 1.27954221  0.03809412  0.10107679] 1
# [-0.11051397 -0.87487632  0.54238635] 1
# [-2.30397511 -1.4592346  -0.61457229] 0
# [-0.42648694  0.91661483  1.36521959] 0
# [-0.84557062  0.07870708 -0.69311428] 0
# [ 0.35324717  0.87648761  1.75265443] 0
# [-0.4268074  -0.5211072   0.27724376] 0
# [ 0.20956676 -1.16213953 -0.98686218] 1
# [-0.69685251  0.68046004 -1.33908749] 0
# [-0.24207181  0.10836972 -0.31895816] 0
# [ 0.29868433 -0.57796574  0.15800114] 0
# [-1.07273495  0.36407951 -0.54895616] 0
# [-0.79996204  2.68988109 -0.6012879 ] 1
# [-0.0323892  -0.25736356  2.3377974 ] 0
# [ 1.37226379  0.94933003  2.39746666] 1
# [ 1.35497403 -1.0535531   0.65107954] 1
# [ 0.58542997  0.76021987 -0.61695099] 0
# [-2.52694845 -1.12335157 -1.25589478] 1
# [-1.17679179  1.34074557 -0.35061541] 1
# [ 1.23998475 -1.5303371  -0.85731637] 1
# [-1.41654837  1.41906333 -0.08078749] 1
# [ 0.68935555 -0.59326136  0.61185825] 1
# [-1.90886319  0.35917926  1.38020384] 1
# [ 1.29070652 -0.58660305 -0.67601436] 0
# [-1.82475662 -0.09518471  1.15610194] 0
# [-1.90447867  1.52815497 -0.63152695] 0
# [ 0.66154122  0.81708199 -0.18515685] 1
# [-0.17333768 -0.11812909  1.90437877] 1
# [ 0.04214408  0.52893299  0.51633793] 0
# [-1.89591324  1.30243933  0.59673899] 1
# [ 0.2903353   0.24081063  0.95798993] 0
# [ 0.88687158 -0.30095392  0.31424913] 0
# [-0.82786798 -0.76938426 -0.42867407] 1
# [-0.44221136 -0.32897523  0.66634059] 1
# [ 0.39187691  1.14426684 -1.33087659] 1
# [ 1.05621719  0.87123042 -1.15998101] 0
# [ 0.58606845 -0.37829512  0.58073312] 1
# [ 0.69598842 -0.56915629  0.63126975] 0
# [-0.93407434 -0.41027144 -0.17195418] 1
# [-1.47748625  1.74215686  0.82200581] 0
# [ 1.20967877 -1.69239151  0.753133  ] 0
# [ 0.772596    0.03617651  0.74550915] 1
# [ 0.60222214  0.32264629  0.21482368] 1
# [-0.00244083 -1.0340389  -0.6143676 ] 0
# [ 0.78587657 -1.01950002 -0.13671371] 1
# [ 0.64031172 -1.19383335 -0.67842615] 1
# [ 0.12559906  0.10893862 -0.44626367] 0
# [-0.73319894  1.02711523 -0.86737841] 0
# [-0.51618063  1.30576289 -0.84867913] 1
# [-0.62435216  1.185727    1.87284505] 0
# [ 0.00998633 -1.13341963  0.65046573] 1
# [-1.24742568  2.18062377  0.22209638] 1

# %% [markdown]
# # Ch 09: Concept 01

# %% [markdown]
# ## Using the CIFAR-10 dataset

# %% [markdown]
# CIFAR-10 데이타 셋을 다운받자.   https://www.cs.toronto.edu/~kriz/cifar.html.
# 여기에서 필요한 함수를 지정

# %%
import pickle

def unpickle(file):
    fo = open(file, 'rb')
    dict = pickle.load(fo, encoding='latin1')
    fo.close()
    return dict

# %% [markdown]
# 각각의 이미지는 colored pixel의 flat vector 모양으로 존재한다.
#
# 우리는 이것을 pixel의 매트릭스 형태로 변환할 것이다.
#
# 먼저 우리는 이것을 grayscale해야한다.
#
# 그다음 입력데이터의 차원수를 더 줄이기 위해서 이미지의 가장자리를 자른다.
#
# 마지막으로 평균 픽셀을 뺀 값을 표준편차로 나눔으로써 입력값을 표준화 한다.

# %%
import numpy as np

def clean(data):
    imgs = data.reshape(data.shape[0], 3, 32, 32)
    grayscale_imgs = imgs.mean(1)
    cropped_imgs = grayscale_imgs[:, 4:28, 4:28]
    img_data = cropped_imgs.reshape(data.shape[0], -1)
    img_size = np.shape(img_data)[1]
    means = np.mean(img_data, axis=1)
    meansT = means.reshape(len(means), 1)
    stds = np.std(img_data, axis=1)
    stdsT = stds.reshape(len(stds), 1)
    adj_stds = np.maximum(stdsT, 1.0 / np.sqrt(img_size))
    normalized = (img_data - meansT) / adj_stds
    return normalized

# %% [markdown]
# 다음은 모든 이미지를 로드하고 전처리하는 함수를 생성한다.

# %%
def read_data(directory):
    names = unpickle('{}/batches.meta'.format(directory))['label_names']
    print('names', names)

    data, labels = [], []
    for i in range(1, 6):
        filename = '{}/data_batch_{}'.format(directory, i)
        batch_data = unpickle(filename)
        if len(data) > 0:
            data = np.vstack((data, batch_data['data']))
            labels = np.hstack((labels, batch_data['labels']))
        else:
            data = batch_data['data']
            labels = batch_data['labels']

    print(np.shape(data), np.shape(labels))

    data = clean(data)
    data = data.astype(np.float32)
    return names, data, labels

# %% [markdown]
# 데이터 세트의 일부 데이터를 프린트해보자.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import random
random.seed(1)

names, data, labels = read_data('./cifar-10-batches-py')

def show_some_examples(names, data, labels):
    plt.figure()
    rows, cols = 4, 4
    random_idxs = random.sample(range(len(data)), rows * cols)
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        j = random_idxs[i]
        plt.title(names[labels[j]])
        img = np.reshape(data[j, :], (24, 24))
        plt.imshow(img, cmap='Greys_r')
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('cifar_examples.png')

show_some_examples(names, data, labels)
# Out:
# names ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# (50000, 3072) (50000,)
